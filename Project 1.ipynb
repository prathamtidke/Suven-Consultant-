# %% [markdown]
# ### Online Coding Internship - Suven Consultants & Technology Pvt. Ltd.
# ## Project - 1
#
# ### Performing Analysis of Meteorological Data : -
# __The Influence of Global Warming on temperature and humidity.__

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# For in notebook graph
# %matplotlib inline

# %%
data = pd.read_csv("weatherHistory.csv")

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.tail() # to view last columns and rows
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
data.shape # it shows we have 96453 rows and 12 columns (rows,columns)
# Out:
# (96453, 12)

# %%
data.info() # For getting info of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
# It show all columns 
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
# we have to check that if we have any missing value
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# It find Unique value of given perticular column
data["Precip Type"].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
# It find mode of perticular column 
mod = data["Precip Type"].mode()
print(mod)
# Out:
# 0    rain
# dtype: object

# %%
data["Precip Type"].isna().sum()
# Out:
# 517

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
# This function delete the perticular column;
data = data.drop(['Loud Cover'],axis = 1)

# %%
# This function tells the perticular column value 
# pre = data['Pressure (millibars)'].tolist()
# print(pre)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Daily Summary'],
#       dtype='object')

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# ...

# %%
# It return type of perticular column 
data.dtypes["Formatted Date"]
# Out:
# dtype('O')

# %% [markdown]
# __This perticular Data column "Formatted Date" is in string form we are converting the ‘Formatted Date’ column to standard Python datetime format.__

# %%
data['Formatted Date'] = pd.to_datetime(data["Formatted Date"],utc = True)

# %%
data.dtypes["Formatted Date"]
# Out:
# datetime64[ns, UTC]

# %%
data
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
data.info()
# Hence we successfully converted in datatype format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 8.8+ MB

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
#        'Daily Summary'],
#       dtype='object')

# %% [markdown]
# __Resample data from hourly to month wise__

# %%
#  Here we setting formatted date as index 
data = data.set_index("Formatted Date")
data
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                                  ...         ...              ...
# 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# ...

# %%
# calculating mean of perticular column and resampling 
# MS stands for monthly starting 
data_mean = data[['Apparent Temperature (C)' , 'Humidity']].resample("MS").mean()
data_mean
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %%
plt.figure(figsize = (12,5))
plt.plot(data_mean["Apparent Temperature (C)"],label = 'Apparent Temp',color = 'Red')
plt.plot(data_mean["Humidity"],label = 'Apparent Temp',color = 'blue',linestyle = 'dashed')
plt.legend(fontsize = 12);

# %% [markdown]
# #### Observation:
# __From the above plot__
#
# * "Humidity" remained constant from 2006 - 2016

# %%
sns.set_style("darkgrid")
sns.barplot(data=data_mean,x = 'Apparent Temperature (C)',y="Humidity", color="g")
plt.title("Relation between Apparent Temperature (C) and Humidity")
plt.show()

# %%
# In barplot we are not able to notice temp but we can easily see that humidity range 0.8 to 0.6

# %%
sns.set_style("darkgrid")
sns.regplot(data=data_mean, x="Apparent Temperature (C)", y="Humidity", color="b")
plt.title("Relation between Apparent Temperature (C) and Humidity")
plt.show()

# %%
# Pair plot for correlation of Apparent temperature & Humidity
sns.set_style("darkgrid")
plt.figure(figsize=(4,4))
plt.title("Correlation between Apparent temperature & Humidity")
sns.heatmap(data= data_mean.corr(), annot=True)
plt.show()

# %%
sns.pairplot(data_mean, kind='scatter')
plt.show()

# %%
# For Apparent Temperature (C)
sns.set_style("darkgrid")
sns.FacetGrid(data,hue="Summary", height=10).map(sns.histplot, "Apparent Temperature (C)").add_legend()
plt.title("Analysis of Weather Conditions with Temperature")
plt.show()

# %%
# For Humidity
sns.set_style("darkgrid")
sns.FacetGrid(data, hue="Summary",height=10).map(sns.histplot, "Humidity").add_legend()
plt.title("Analysis of Weather Conditions with Humidity")
plt.show()

# %%
resample=data[['Apparent Temperature (C)', 'Humidity']].resample('MS').mean()
resample
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %%
jan_data = resample[resample.index.month==1]
plt.figure(figsize=(10, 5))
plt.title('Variation of Apparent Temperature vs Humidity', fontsize=20)
plt.xlabel("January", fontsize=15)
sns.lineplot(data=jan_data, marker='s')
# Out:
# <AxesSubplot:title={'center':'Variation of Apparent Temperature vs Humidity'}, xlabel='January'>

# %%
feb_data = resample[resample.index.month==2]
plt.figure(figsize=(10, 5))
plt.title('Variation of Apparent Temperature vs Humidity', fontsize=20)
plt.xlabel("February", fontsize=15)
sns.lineplot(data=feb_data, marker='s')
# Out:
# <AxesSubplot:title={'center':'Variation of Apparent Temperature vs Humidity'}, xlabel='February'>

# %%
march_data = resample[resample.index.month==3]
plt.figure(figsize=(10, 5))
plt.title('Variation of Apparent Temperature vs Humidity', fontsize=20)
plt.xlabel("March", fontsize=15)
sns.lineplot(data=march_data, marker='s')
# Out:
# <AxesSubplot:title={'center':'Variation of Apparent Temperature vs Humidity'}, xlabel='March'>

# %%
april_data = resample[resample.index.month==4]
plt.figure(figsize=(10, 5))
plt.title('Variation of Apparent Temperature vs Humidity', fontsize=20)
plt.xlabel("April", fontsize=15)
sns.lineplot(data=april_data, marker='s')
# Out:
# <AxesSubplot:title={'center':'Variation of Apparent Temperature vs Humidity'}, xlabel='April'>

# %% [markdown]
# ### Conclusions : -
# * As we can see in the above images, there are many ups and downs in the temperature and the average humidity has remained constant throughout the 10 years.So, We can conclude that global warming has caused an uncertainty in the temperature over the past 10 years.
#
# * Increase in average apparent temperature can be seen in the year 2009 then again it dropped in 2010 then there was a slight increase in 2011 then a significant drop is observed in 2015 and again it increased in 2016.
#
# * According to Null Hypothesis (H0) both increases due to Global Warming is proven wrong here, and thus null hypothesis failed.
